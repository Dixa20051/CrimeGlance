# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
import io

# %%
#reading the uploaded file
df=pd.read_csv(r"C:\\Users\\himanshu rai\\Desktop\\node\\finalProject\\Crime rate detection data.csv")

# %%
df
# Out:
#      DistCode  Year  StateCode     StateName    DistName  TotalPop1000
# 0           1  2011         14  Chhattisgarh        Durg       5465.00  \
# 1           2  2011         14  Chhattisgarh      Bastar       3090.83
# 2           3  2011         14  Chhattisgarh      Raipur       5896.40
# 3           4  2011         14  Chhattisgarh    Bilaspur       5728.51
# 4           5  2011         14  Chhattisgarh     Raigarh       2345.65
# ..        ...   ...        ...           ...         ...           ...
# 300       913  2011         15     Jharkhand  Hazaribagh       8270.32
# 301       914  2011         15     Jharkhand     Dhanbad       3365.06
# 302       915  2011         15     Jharkhand     Palamau       3989.63
# 303       916  2011         15     Jharkhand      Ranchi       5532.72
# 304       917  2011         15     Jharkhand   Singhbhum       4861.32
#
#      TotalMale1000  TotalFemale1000  TotalLITPop  MaleLITPop  FemaleLITPop
# ...

# %%
df.insert(19,"SafeMeasure",0)

# %%
np.max(df.Crime_rate)
# Out:
# 566.6982025

# %%
np.mean(df.Crime_rate)
# Out:
# 144.17592170390165

# %%
df.columns
# Out:
# Index(['DistCode', 'Year', 'StateCode', 'StateName', 'DistName',
#        'TotalPop1000', 'TotalMale1000', 'TotalFemale1000', 'TotalLITPop',
#        'MaleLITPop', 'FemaleLITPop', 'PerCapita1000', 'TotalPop', 'MALE_LIT',
#        'FEMALE_LIT', 'OVERALL_LIT', 'Per capita', 'TotalCrime', 'Crime_rate',
#        'SafeMeasure', 'GDPP'],
#       dtype='object')

# %%
for i in range(0,len(df)):
    if df.Crime_rate[i]>=150:
      df.SafeMeasure[i]=0
    elif df['Crime_rate'][i]>100 and df['Crime_rate'][i]<150:
      df.SafeMeasure[i]=1
    else:
      df.SafeMeasure[i]=2
# Out:
# C:\Users\himanshu rai\AppData\Local\Temp\ipykernel_8552\497462529.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.SafeMeasure[i]=0
# C:\Users\himanshu rai\AppData\Local\Temp\ipykernel_8552\497462529.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.SafeMeasure[i]=0
# C:\Users\himanshu rai\AppData\Local\Temp\ipykernel_8552\497462529.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.SafeMeasure[i]=0
# ...

# %%
x = df[['GDPP','TotalPop','MALE_LIT']]
y= df['SafeMeasure']
x_train,x_test,y_train,y_test = train_test_split(x,y,random_state=2,test_size=0.2,shuffle=True)

# %%
clf=DecisionTreeClassifier()

# %%
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf.predict(x_test)
# Out:
# array([0, 2, 0, 0, 2, 2, 0, 0, 2, 0, 2, 0, 0, 0, 0, 2, 1, 0, 0, 2, 0, 0,
#        0, 2, 0, 0, 2, 2, 2, 2, 0, 1, 1, 2, 2, 2, 1, 0, 2, 0, 0, 0, 0, 2,
#        0, 2, 0, 0, 2, 0, 0, 0, 2, 1, 2, 0, 2, 1, 0, 2, 0], dtype=int64)

# %%
clf.score(x_test,y_test)
# Out:
# 0.5245901639344263

# %%
#for kanpur(should be moderate safe)
cap=87296*0.36
pop=3234000*0.87
lit=88.34*0.96
gdpp=cap/pop
result=clf.predict([[gdpp,pop,lit]])
if result==0:
    print("not safe")
elif result==1:
  print("moderate safe")
else:
  print("safe")
# Out:
# moderate safe
# c:\Users\himanshu rai\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
#for coimbatore(should be safe)
cap=189937*0.36
pop=3009000*0.87
lit=94.46*0.96
gdpp=cap/pop
result=clf.predict([[gdpp,pop,lit]])
if result==0:
    print("not safe")
elif result==1:
  print("moderate safe")
else:
  print("safe")
# Out:
# not safe
# c:\Users\himanshu rai\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
#for kolkata(should be safe)
cap=339000*0.36
pop=14900000*0.87
lit=86.31*0.96
gdpp=cap/pop
result=clf.predict([[gdpp,pop,lit]])
if result==0:
    print("not safe")
elif result==1:
  print("moderate safe")
else:
  print("safe")
# Out:
# moderate safe
# c:\Users\himanshu rai\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
#for delhi(should be not safe)
cap=300000*0.36
pop=32066000*0.87
lit=90.94*0.96
gdpp=cap/pop
result=clf.predict([[gdpp,pop,lit]])
if result==0:
    print("not safe")
elif result==1:
  print("moderate safe")
else:
  print("safe")
# Out:
# safe
# c:\Users\himanshu rai\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
